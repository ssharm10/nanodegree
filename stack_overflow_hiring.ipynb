# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from IPython import display
# %matplotlib inline
from collections import defaultdict
df = pd.read_csv('./survey-results-public.csv')
df.head()
# Out:
#    Respondent                                       Professional  \
# 0           1                                            Student
# 1           2                                            Student
# 2           3                             Professional developer
# 3           4  Professional non-developer who sometimes write...
# 4           5                             Professional developer
#
#                 ProgramHobby         Country      University  \
# 0                  Yes, both   United States              No
# 1                  Yes, both  United Kingdom  Yes, full-time
# 2                  Yes, both  United Kingdom              No
# 3                  Yes, both   United States              No
# 4  Yes, I program as a hobby     Switzerland              No
#
#                          EmploymentStatus  \
# 0  Not employed, and not looking for work
# 1                      Employed part-time
# 2                      Employed full-time
# ...

# %%
dfimp = df.filter(regex='^Important',axis=1).drop('ImportantBenefits',axis=1)
dfimp.head(10)
# Out:
#   ImportantHiringAlgorithms ImportantHiringTechExp  \
# 0                 Important              Important
# 1                 Important              Important
# 2                       NaN                    NaN
# 3        Somewhat important     Somewhat important
# 4                       NaN                    NaN
# 5        Not very important     Not very important
# 6            Very important              Important
# 7        Somewhat important     Somewhat important
# 8                       NaN                    NaN
# 9                       NaN                    NaN
#
#   ImportantHiringCommunication ImportantHiringOpenSource ImportantHiringPMExp  \
# 0                    Important        Somewhat important            Important
# 1                    Important                 Important   Somewhat important
# 2                          NaN                       NaN                  NaN
# 3               Very important            Very important   Somewhat important
# ...

# %%
#For every column in dfimp data frame i want to calculate the percentage of people that has responded with unique answers
#for example - if I were to do this for the first column
print(dfimp['ImportantHiringAlgorithms'].value_counts()/dfimp.shape[0])
# Out:
# Important               0.230620
# Somewhat important      0.153526
# Very important          0.125759
# Not very important      0.040726
# Not at all important    0.006694
# Name: ImportantHiringAlgorithms, dtype: float64

# %%
#Question - How can I use df.apply to repeat the above procedure for all the columns in the dataframe and store the percentages in a new dataframe?

# %%
#I want to calculate an avg score for every column based on the following dictionary:
score = {'Not at all important': 0,'Not very important': 2.5,
         'Somewhat important': 5.0,'Important': 7.5,'Very important': 10}
